# %% [markdown]
# <a href="https://colab.research.google.com/github/luisxgv/atividade-extra-1-prof.-Claudomiro-/blob/main/atividade%20extra%201%20c%C3%B3digo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

n_niveis = int(input("Digite o número de níveis de quantização: "))
n_bits = math.ceil(math.log2(n_niveis))

print(f"\nPara {n_niveis} níveis, são necessários {n_bits} bits.")
print("As combinações possíveis são:")

for i in range(n_niveis):
    combinacao = bin(i)[2:].zfill(n_bits)
    print(f"Nível {i}: {combinacao}")

# %%
binario = input("Digite o valor binário: ")

decimal = 0
potencia = 0

for bit in binario[::-1]:
  if bit == '1':
      valor_da_casa = 2 ** potencia
      decimal += valor_da_casa
      print(f"Bit 1 encontrando na posição {potencia}: somando 2^{potencia} ({valor_da_casa})")
  else:
      print(f"Bit 0 na posição {potencia}: não soma nada.")

  potencia += 1

print("-" * 30)
print(f"O resultado é: Binário {binario} é {decimal} em decimal.")

# %%
decimal = int(input("Digite um número decimal: "))
numero_original = decimal

bits = []

if decimal == 0:
    bits.append(0)
else:
    while decimal > 0:
        resto = decimal % 2
        bits.append(resto)

        print(f"{decimal} dividido por 2 dá resto {resto}")

        decimal = decimal // 2


bits.reverse()

resultado_binario = "".join(map(str, bits))

print("-" * 30)
print(f"O número {numero_original} em binário é: {resultado_binario}")

# %%
print("Escolha a base de origem: 1-Octal, 2-Hexa, 3-Decimal")
opcao = input("Opção: ")
valor_original = input("Digite o valor: ")


if opcao == '1':
    decimal_temp = int(valor_original, 8)
    binario = bin(decimal_temp)[2:]
    origem = "Octal"
elif opcao == '2': #
    decimal_temp = int(valor_original, 16)
    binario = bin(decimal_temp)[2:]
    origem = "Hexa"
else:
    decimal_temp = int(valor_original)
    binario = bin(decimal_temp)[2:]
    origem = "Decimal"


print("-" * 40)
print(f"Valor Original ({origem}): {valor_original}")
print(f"Ponte Binária: {binario}")
print("-" * 40)



v_decimal = int(binario, 2)
v_octal = oct(v_decimal)[2:]
v_hexa = hex(v_decimal)[2:].upper()

print(f"➡️ Binário para Decimal: {v_decimal}")
print(f"➡️ Binário para Octal: {v_octal}")
print(f"➡️ Binário para Hexa: {v_hexa}")
